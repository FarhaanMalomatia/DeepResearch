# %% [markdown]
# <a href="https://colab.research.google.com/github/FarhaanMalomatia/DeepResearch/blob/main/open_deep_researcher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade --quiet  langchain-huggingface text-generation transformers google-search-results numexpr langchainhub sentencepiece jinja2 bitsandbytes accelerate langchain-community tavily-python langgraph pypdf faiss-cpu unstructured langchain-google-genai nest_asyncio
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.0/91.0 kB 6.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 35.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 68.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.7/69.7 MB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 342.1/342.1 kB 24.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 54.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.4/151.4 kB 11.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.7/300.7 kB 20.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.7/30.7 MB 26.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 40.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 39.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 413.7/413.7 kB 24.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 40.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 87.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 73.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 47.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 897.0 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 1.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 50.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.6/590.6 kB 27.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.6/167.6 kB 15.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 60.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.6/113.6 kB 8.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.6/114.6 kB 9.1 MB/s eta 0:00:00
#   Building wheel for google-search-results (setup.py) ... done
#   Building wheel for langdetect (setup.py) ... done

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
import asyncio
import aiohttp
import json
from google.colab import userdata
from bs4 import BeautifulSoup
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.schema import AIMessage, HumanMessage, SystemMessage

gemini_chat = ChatGoogleGenerativeAI(model="gemini-2.0-flash",
                                     google_api_key= userdata.get("GEMINI_API_KEY")
                                     )
gemini_chat_new = ChatGoogleGenerativeAI(model="gemini-2.0-flash",
                                     google_api_key= userdata.get("GEMINI_FP03_API_KEY")
                                     )


# ============================
# Asynchronous Helper Functions
# ============================

async def generate_search_queries_async(session, user_query):
    """
    Ask the LLM to produce up to four precise search queries (in Python list format)
    based on the user’s query.
    """
    prompt = (
        "You are an expert research assistant. Given the user's query, generate up to four distinct, "
        "precise search queries that would help gather comprehensive information on the topic. "
        "Return only a Python list of strings, for example: ['query1', 'query2', 'query3']."
    )
    messages = [
        {"role": "system", "content": "You are a helpful and precise research assistant."},
        {"role": "user", "content": f"User Query: {user_query}\n\n{prompt}"}
    ]
    response = gemini_chat.invoke(messages)
    print("response in generate_search_queries_async: ", response)
    if response:
        try:
            # Expect exactly a Python list (e.g., "['query1', 'query2']")
            content = response.content.strip()
            if content.startswith("```"):
                # Remove the first line (```python) and the last line (```)
                lines = content.splitlines()
                if lines[-1].strip() == "```":
                    content = "\n".join(lines[1:-1])
            search_queries = eval(content)
            if isinstance(search_queries, list):
                return search_queries
            else:
                print("LLM did not return a list. Response:", response)
                return []
        except Exception as e:
            print("Error parsing search queries:", e, "\nResponse:", response)
            return []
    return []


async def perform_search_async(session, query):
    """
    Asynchronously perform a Google search using the Custom Search JSON API for the given query.
    Returns a list of result URLs.
    """
    # Replace with your own API key and Custom Search Engine ID (CX)
    API_KEY = userdata.get('GOOGLE_SEARCH_API_KEY')
    CSE_ID = userdata.get('GOOGLE_CUSTOM_SEARCH_ENGINE_ID')

    params = {
        "q": query,
        "key": API_KEY,
        "cx": CSE_ID,
    }

    # URL for Google's Custom Search JSON API
    GOOGLE_SEARCH_URL = "https://www.googleapis.com/customsearch/v1"

    try:
        async with session.get(GOOGLE_SEARCH_URL, params=params) as resp:
            if resp.status == 200:
                results = await resp.json()
                if "items" in results:
                    # Extract links from the search results
                    links = [item.get("link") for item in results["items"] if "link" in item]
                    return links
                else:
                    print("No items in Google search response.")
                    return []
            else:
                text = await resp.text()
                print(f"Google Custom Search API error: {resp.status} - {text}")
                return []
    except Exception as e:
        print("Error performing Google Custom Search:", e)
        return []


async def fetch_webpage_text_async(session, url):
    """
    Asynchronously retrieve the text content of a webpage using BeautifulSoup.
    """

    try:
        # Fetch the webpage content
        async with session.get(url) as resp:
            if resp.status == 200:
                html_content = await resp.text()

                # Parse the HTML content with BeautifulSoup
                soup = BeautifulSoup(html_content, 'html.parser')

                # Extract and return the main text content of the page
                # You can customize this depending on the HTML structure of the webpage
                page_text = soup.get_text()
                return page_text
            else:
                print(f"Error fetching {url}: {resp.status}")
                return ""
    except Exception as e:
        print("Error fetching webpage text:", e)
        return ""


async def is_page_useful_async(session, user_query, page_text):
    """
    Ask the LLM if the provided webpage content is useful for answering the user's query.
    The LLM must reply with exactly "Yes" or "No".
    """
    prompt = (
        "You are a critical research evaluator. Given the user's query and the content of a webpage, "
        "determine if the webpage contains information relevant and useful for addressing the query. "
        "Respond with exactly one word: 'Yes' if the page is useful, or 'No' if it is not. Do not include any extra text."
    )
    messages = [
        {"role": "system", "content": "You are a strict and concise evaluator of research relevance."},
        {"role": "user", "content": f"User Query: {user_query}\n\nWebpage Content (first 20000 characters):\n{page_text[:20000]}\n\n{prompt}"}
    ]
    response = await gemini_chat_new.invoke(messages)
    print("response in is_page_useful_async: ", response)
    if response:
        answer = response.strip()
        if answer in ["Yes", "No"]:
            return answer
        else:
            # Fallback: try to extract Yes/No from the response.
            if "Yes" in answer:
                return "Yes"
            elif "No" in answer:
                return "No"
    return "No"


async def extract_relevant_context_async(session, user_query, search_query, page_text):
    """
    Given the original query, the search query used, and the page content,
    have the LLM extract all information relevant for answering the query.
    """
    prompt = (
        "You are an expert information extractor. Given the user's query, the search query that led to this page, "
        "and the webpage content, extract all pieces of information that are relevant to answering the user's query. "
        "Return only the relevant context as plain text without commentary."
    )
    messages = [
        {"role": "system", "content": "You are an expert in extracting and summarizing relevant information."},
        {"role": "user", "content": f"User Query: {user_query}\nSearch Query: {search_query}\n\nWebpage Content (first 20000 characters):\n{page_text[:20000]}\n\n{prompt}"}
    ]
    response = await gemini_chat.invoke(messages)
    print("response in extract_relevant_context_async: ", response)
    if response:
        return response.strip()
    return ""


async def get_new_search_queries_async(session, user_query, previous_search_queries, all_contexts):
    """
    Based on the original query, the previously used search queries, and all the extracted contexts,
    ask the LLM whether additional search queries are needed. If yes, return a Python list of up to four queries;
    if the LLM thinks research is complete, it should return "<done>".
    """
    context_combined = "\n".join(all_contexts)
    prompt = (
        "You are an analytical research assistant. Based on the original query, the search queries performed so far, "
        "and the extracted contexts from webpages, determine if further research is needed. "
        "If further research is needed, provide up to four new search queries as a Python list (for example, "
        "['new query1', 'new query2']). If you believe no further research is needed, respond with exactly <done>."
        "\nOutput only a Python list or the token <done> without any additional text."
    )
    messages = [
        {"role": "system", "content": "You are a systematic research planner."},
        {"role": "user", "content": f"User Query: {user_query}\nPrevious Search Queries: {previous_search_queries}\n\nExtracted Relevant Contexts:\n{context_combined}\n\n{prompt}"}
    ]
    response = await gemini_chat_new.invoke(messages)
    print("response in get_new_search_queries_async: ", response)
    if response:
        cleaned = response.strip()
        if cleaned == "<done>":
            return "<done>"
        try:
            new_queries = eval(cleaned)
            if isinstance(new_queries, list):
                return new_queries
            else:
                print("LLM did not return a list for new search queries. Response:", response)
                return []
        except Exception as e:
            print("Error parsing new search queries:", e, "\nResponse:", response)
            return []
    return []


async def generate_final_report_async(session, user_query, all_contexts):
    """
    Generate the final comprehensive report using all gathered contexts.
    """
    context_combined = "\n".join(all_contexts)
    prompt = (
        "You are an expert researcher and report writer. Based on the gathered contexts below and the original query, "
        "write a comprehensive, well-structured, and detailed report that addresses the query thoroughly. "
        "Include all relevant insights and conclusions without extraneous commentary."
    )
    messages = [
        {"role": "system", "content": "You are a skilled report writer."},
        {"role": "user", "content": f"User Query: {user_query}\n\nGathered Relevant Contexts:\n{context_combined}\n\n{prompt}"}
    ]
    report = await gemini_chat.invoke(messages)
    print("report in generate_final_report_async: ", report)
    return report


async def process_link(session, link, user_query, search_query):
    """
    Process a single link: fetch its content, judge its usefulness, and if useful, extract the relevant context.
    """
    print(f"Fetching content from: {link}")
    page_text = await fetch_webpage_text_async(session, link)
    if not page_text:
        return None
    usefulness = await is_page_useful_async(session, user_query, page_text)
    print(f"Page usefulness for {link}: {usefulness}")
    if usefulness == "Yes":
        context = await extract_relevant_context_async(session, user_query, search_query, page_text)
        if context:
            print(f"Extracted context from {link} (first 200 chars): {context[:200]}")
            return context
    return None


# =========================
# Main Asynchronous Routine
# =========================

async def async_main():
    user_query = input("Enter your research query/topic: ").strip()
    iter_limit_input = input("Enter maximum number of iterations (default 10): ").strip()
    iteration_limit = int(iter_limit_input) if iter_limit_input.isdigit() else 10

    aggregated_contexts = []    # All useful contexts from every iteration
    all_search_queries = []     # Every search query used across iterations
    iteration = 0

    async with aiohttp.ClientSession() as session:
        # ----- INITIAL SEARCH QUERIES -----
        new_search_queries = await generate_search_queries_async(session, user_query)
        if not new_search_queries:
            print("No search queries were generated by the LLM. Exiting.")
            return
        all_search_queries.extend(new_search_queries)

        # ----- ITERATIVE RESEARCH LOOP -----
        while iteration < iteration_limit:
            print(f"\n=== Iteration {iteration + 1} ===")
            iteration_contexts = []

            # For each search query, perform SERPAPI searches concurrently.
            search_tasks = [perform_search_async(session, query) for query in new_search_queries]
            search_results = await asyncio.gather(*search_tasks)

            # Aggregate all unique links from all search queries of this iteration.
            # Map each unique link to the search query that produced it.
            unique_links = {}
            for idx, links in enumerate(search_results):
                query = new_search_queries[idx]
                for link in links:
                    if link not in unique_links:
                        unique_links[link] = query

            print(f"Aggregated {len(unique_links)} unique links from this iteration.")

            # Process each link concurrently: fetch, judge, and extract context.
            link_tasks = [
                process_link(session, link, user_query, unique_links[link])
                for link in unique_links
            ]
            link_results = await asyncio.gather(*link_tasks)

            # Collect non-None contexts.
            for res in link_results:
                if res:
                    iteration_contexts.append(res)

            if iteration_contexts:
                aggregated_contexts.extend(iteration_contexts)
            else:
                print("No useful contexts were found in this iteration.")

            # ----- ASK THE LLM IF MORE SEARCHES ARE NEEDED -----
            new_search_queries = await get_new_search_queries_async(session, user_query, all_search_queries, aggregated_contexts)
            if new_search_queries == "<done>":
                print("LLM indicated that no further research is needed.")
                break
            elif new_search_queries:
                print("LLM provided new search queries:", new_search_queries)
                all_search_queries.extend(new_search_queries)
            else:
                print("LLM did not provide any new search queries. Ending the loop.")
                break

            iteration += 1

        # ----- FINAL REPORT -----
        print("\nGenerating final report...")
        final_report = await generate_final_report_async(session, user_query, aggregated_contexts)
        print("\n==== FINAL REPORT ====\n")
        print(final_report)


def main():
    asyncio.run(async_main())


if __name__ == "__main__":
    main()
# Out:
# Enter your research query/topic: How has the AI such as Chatgpt impacted programmers/coders/software engineers since it's arrival, what will the future of programmers/coders/software engineers be in the future, research deeply
# Enter maximum number of iterations (default 10): 10
# response in generate_search_queries_async:  content='```python\n[\n    "impact of AI tools like ChatGPT on software development workflows",\n    "future roles and skills for programmers in an AI-driven software engineering landscape",\n    "ChatGPT and similar AI code generation tools: benefits, limitations, and ethical considerations for software engineers",\n    "evolution of software engineering jobs and required expertise due to AI automation"\n]\n```' additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []} id='run-42b91f01-18b1-466b-9782-2e7b8970c575-0' usage_metadata={'input_tokens': 108, 'output_tokens': 80, 'total_tokens': 188, 'input_token_details': {'cache_read': 0}}
#
# === Iteration 1 ===
# Aggregated 36 unique links from this iteration.
# Fetching content from: https://arxiv.org/html/2405.12195v1
# Fetching content from: https://newsletter.pragmaticengineer.com/p/ai-tooling-2024
# Fetching content from: https://www.sciencedirect.com/science/article/pii/S0268401223000233
# Fetching content from: https://www.mckinsey.com/capabilities/mckinsey-digital/our-insights/the-economic-potential-of-generative-ai-the-next-productivity-frontier
# Fetching content from: https://www.sciencedirect.com/science/article/pii/S2666990024000120
# Fetching content from: https://medium.com/@colinbaird_51123/tips-for-building-an-application-from-scratch-with-chatgpt-as-a-non-developer-9b256336d6aa
# Fetching content from: https://www.goldmansachs.com/insights/articles/generative-ai-could-raise-global-gdp-by-7-percent
# Fetching content from: https://extendedstudies.ucsd.edu/news-events/extended-studies-blog/will-ai-replace-programmers-navigating-the-future-of-coding
# Fetching content from: https://www.linkedin.com/posts/kmtan_2024-in-review-how-ais-evolution-will-transform-activity-7267863652186177536-KaM2
# Fetching content from: https://www.gartner.com/en/topics/generative-ai
# Fetching content from: https://onlinecs.baylor.edu/news/will-ai-replace-SWEs
# Fetching content from: https://brainhub.eu/library/software-developer-age-of-ai
# Fetching content from: https://www.forbes.com/sites/jackkelly/2024/12/17/predictions-for-the-tech-job-market-in-2025/
# Fetching content from: https://www.linkedin.com/posts/aamer-baig_the-gen-ai-skills-revolution-rethinking-activity-7273773745318588417-TBpa
# Fetching content from: https://ep.jhu.edu/news/the-impact-of-ai-on-the-engineering-field/
# Fetching content from: https://www.mckinsey.com/capabilities/people-and-organizational-performance/our-insights/the-organization-of-the-future-enabled-by-gen-ai-driven-by-people
# Fetching content from: https://www.gartner.com/doc/reprints?id=1-2IPGQWUX&ct=240903&st=sb&?ocid=eml_pg454105_gdc_comm_gh&mkt_tok=MTU3LUdRRS0zODIAAAGYH0QuIQ5A3vVpwy_vVle5ooj6bsIlfdBt6YgT2ty_WCKK4-OzV8mjrJbAN7wnr1VTAlA7rC6OzNzkjBORtRmm3sw7KeRvf31YTUyIMZsqKsehkNJW1FtmS89y
# Fetching content from: https://www.mckinsey.com/featured-insights/future-of-work/ai-automation-and-the-future-of-work-ten-things-to-solve-for
# Fetching content from: https://blog.getaura.ai/ai-jobs
# Fetching content from: https://www.mckinsey.com/capabilities/mckinsey-digital/our-insights/the-gen-ai-skills-revolution-rethinking-your-talent-strategy
# Fetching content from: https://softwareengineeringexperiences.quora.com/As-a-software-engineer-is-it-considered-cheating-to-use-OpenAIs-ChatGPT-to-aid-me-complete-coding-tasks-Should-I-wr
# Fetching content from: https://www.linkedin.com/posts/rpandey1234_if-youre-blindly-copying-code-from-chatgpt-activity-7211488337138700288-rPcH
# Fetching content from: https://direct.mit.edu/dint/article/6/1/201/118839/The-Limitations-and-Ethical-Considerations-of
# Fetching content from: https://stackoverflow.blog/2024/12/31/generative-ai-is-not-going-to-build-your-engineering-team-for-you/
# Fetching content from: https://circleci.com/blog/risks-rewards-generative-ai/
# Fetching content from: https://www.quora.com/As-a-junior-software-developer-should-I-be-ashamed-for-using-ChatGPT-both-for-helping-me-write-code-and-using-it-to-gather-information
# Fetching content from: https://arxiv.org/html/2408.10554v1
# Fetching content from: https://www.harvardonline.harvard.edu/blog/benefits-limitations-generative-ai
# Fetching content from: https://www.reddit.com/r/artificial/comments/1bh4jl3/is_devin_ai_really_going_to_takeover_software/
# Fetching content from: https://dev.to/jdbar/how-software-development-is-changing-forever-and-how-youll-need-to-change-with-it-1jih
# Fetching content from: https://www.reddit.com/r/ArtificialInteligence/comments/10sasj1/is_computer_science_one_of_the_most_threatened/
# Fetching content from: https://www.linkedin.com/pulse/how-i-transitioned-ai-engineer-zahiruddin-tavargere-ivxyc
# Fetching content from: https://www.quora.com/If-AI-replaces-software-engineers-in-20-years-what-else-can-we-do-for-a-job-that-won-t-be-automated-and-can-make-a-great-living-Should-I-switch-careers-now
# Fetching content from: https://www.mckinsey.com/mgi/our-research/generative-ai-and-the-future-of-work-in-america
# Fetching content from: https://www.quora.com/Will-AI-replace-the-job-of-a-software-engineer-developers-and-many-more-IT-professions-in-the-coming-future
# Fetching content from: https://workplace.stackexchange.com/questions/189648/junior-software-developer-looking-for-career-advice-due-to-worry-of-job-security
# Error fetching https://www.sciencedirect.com/science/article/pii/S0268401223000233: 403
# Error fetching https://www.sciencedirect.com/science/article/pii/S2666990024000120: 403
# Error fetching webpage text: Connector is closed.
# WARNING:langchain_google_genai.chat_models:Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 Resource has been exhausted (e.g. check quota)..
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-561fc61ac5e5> in <cell line: 0>()
#     328
#     329 if __name__ == "__main__":
# --> 330     main()
#
# <ipython-input-12-561fc61ac5e5> in main()
#     324
#     325 def main():
# --> 326     asyncio.run(async_main())
#     327
#     328
#
# /usr/local/lib/python3.11/dist-packages/nest_asyncio.py in run(main, debug)
#      28         task = asyncio.ensure_future(main)
#      29         try:
# ---> 30             return loop.run_until_complete(task)
#      31         finally:
#      32             if not task.done():
#
# /usr/local/lib/python3.11/dist-packages/nest_asyncio.py in run_until_complete(self, future)
#      96                 raise RuntimeError(
#      97                     'Event loop stopped before Future completed.')
# ---> 98             return f.result()
#      99
#     100     def _run_once(self):
#
# /usr/lib/python3.11/asyncio/futures.py in result(self)
#     201         self.__log_traceback = False
#     202         if self._exception is not None:
# --> 203             raise self._exception.with_traceback(self._exception_tb)
#     204         return self._result
#     205
#
# /usr/lib/python3.11/asyncio/tasks.py in __step(***failed resolving arguments***)
#     275                 # We use the `send` method directly, because coroutines
#     276                 # don't have `__iter__` and `__next__` methods.
# --> 277                 result = coro.send(None)
#     278             else:
#     279                 result = coro.throw(exc)
#
# <ipython-input-12-561fc61ac5e5> in async_main()
#     290                 for link in unique_links
#     291             ]
# --> 292             link_results = await asyncio.gather(*link_tasks)
#     293
#     294             # Collect non-None contexts.
#
# /usr/lib/python3.11/asyncio/tasks.py in __wakeup(self, future)
#     347     def __wakeup(self, future):
#     348         try:
# --> 349             future.result()
#     350         except BaseException as exc:
#     351             # This may also be a cancellation.
#
# /usr/lib/python3.11/asyncio/tasks.py in __step(***failed resolving arguments***)
#     275                 # We use the `send` method directly, because coroutines
#     276                 # don't have `__iter__` and `__next__` methods.
# --> 277                 result = coro.send(None)
#     278             else:
#     279                 result = coro.throw(exc)
#
# <ipython-input-12-561fc61ac5e5> in process_link(session, link, user_query, search_query)
#     234     if not page_text:
#     235         return None
# --> 236     usefulness = await is_page_useful_async(session, user_query, page_text)
#     237     print(f"Page usefulness for {link}: {usefulness}")
#     238     if usefulness == "Yes":
#
# <ipython-input-12-561fc61ac5e5> in is_page_useful_async(session, user_query, page_text)
#     134         {"role": "user", "content": f"User Query: {user_query}\n\nWebpage Content (first 20000 characters):\n{page_text[:20000]}\n\n{prompt}"}
#     135     ]
# --> 136     response = await gemini_chat_new.invoke(messages)
#     137     print("response in is_page_useful_async: ", response)
#     138     if response:
#
# TypeError: object AIMessage can't be used in 'await' expression

# %%
How has the AI such as Chatgpt impacted programmers/coders/software engineers since it's arrival, what will the future of programmers/coders/software engineers be in the future, research deeply
